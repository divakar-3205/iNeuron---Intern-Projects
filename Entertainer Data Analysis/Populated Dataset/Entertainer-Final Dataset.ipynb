# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
#eb= Entertainer basic table
#ebt = entertainer breakthrough
#el = entertainer lastwork
eb = pd.read_excel('/content/drive/MyDrive/Entertainer Data Analysis/Entertainer - Basic Info.xlsx')

# %%
eb.head(5)
# Out:
#        Entertainer Gender (traditional)  Birth Year
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922

# %%
ebt = pd.read_excel('/content/drive/MyDrive/Entertainer Data Analysis/Entertainer - Breakthrough Info.xlsx')
ebt.drop('Entertainer',inplace=True,axis=1)
ebt.head()
# Out:
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# 3                          Of Human Bondage                           1935.0
# 4                      Life with Elilzabeth                           1976.0

# %%
el = pd.read_excel('/content/drive/MyDrive/Entertainer Data Analysis/Entertainer - Last work Info.xlsx')
el.drop('Entertainer',inplace=True,axis=1)
el.head(5)
# Out:
#   Gender (traditional)  Birth Year
# 0                    F        1988
# 1                    F        1975
# 2                    F        1942
# 3                    F        1908
# 4                    F        1922

# %%
main_01 = pd.concat([eb,ebt],axis=1)
main_01.head(5)
# Out:
#        Entertainer Gender (traditional)  Birth Year  \
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# ...

# %%
main=pd.concat([main_01,el],axis=1)
main.head(5)
# Out:
#        Entertainer Gender (traditional)  Birth Year  \
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy  \
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# ...

# %%
#saving this file into excel file
new_file ='Entertainer-Finalised Data.xlsx'
main.to_excel(new_file)
